# %%
import pandas as pd

# %%
data = pd.read_csv('test_SOLID')

# %%
data
# Out:
#       Unnamed: 0  MS.SubClass  MS.Zoning_C (all)  MS.Zoning_FV  \
# 0              0           30                  0             0
# 1              1          120                  0             0
# 2              2           30                  1             0
# 3              3           70                  0             0
# 4              4           60                  0             0
# ...          ...          ...                ...           ...
# 1812        1812          120                  0             0
# 1813        1813           45                  0             0
# 1814        1814           60                  0             0
# 1815        1815           20                  0             0
# 1816        1816           50                  0             0
#
#       MS.Zoning_I (all)  MS.Zoning_RH  MS.Zoning_RL  MS.Zoning_RM  \
# 0                     0             0             1             0
# 1                     0             0             1             0
# ...

# %%
data.shape
# Out:
# (1817, 30)
